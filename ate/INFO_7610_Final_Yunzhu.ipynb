# %%
# !pip install transformers datasets seqeval sentencepiece -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !python ate_prepare_data.py
# Out:
# Parsing training XML …
# Parsing test XML …
# Saving the dataset (1/1 shards): 100% 2736/2736 [00:00<00:00, 89320.39 examples/s]
# Saving the dataset (1/1 shards): 100% 305/305 [00:00<00:00, 16475.37 examples/s]
# Saving the dataset (1/1 shards): 100% 800/800 [00:00<00:00, 63404.76 examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['tokens', 'tags'],
#         num_rows: 2736
#     })
#     validation: Dataset({
#         features: ['tokens', 'tags'],
#         num_rows: 305
#     })
#     test: Dataset({
#         features: ['tokens', 'tags'],
#         num_rows: 800
#     })
# })
#
# Train: 2736 | Val: 305 | Test: 800
# Saved to: ate_data/
#
# Example:
#   Enjoy!!!             O

# %%
# !rm -rf ate_output_deberta

# %%
# !python ate_train_deberta_fixed.py
# Out:
# Loading data from ate_data ...
# Loading tokenizer: microsoft/deberta-base ...
# config.json: 100% 474/474 [00:00<00:00, 2.03MB/s]
# tokenizer_config.json: 100% 52.0/52.0 [00:00<00:00, 189kB/s]
# ...
# vocab.json: 899kB [00:00, 100MB/s]
# merges.txt: 456kB [00:00, 111MB/s]
# Map: 100% 2736/2736 [00:00<00:00, 3487.46 examples/s]
# Map: 100% 305/305 [00:00<00:00, 4536.70 examples/s]
# Map: 100% 800/800 [00:00<00:00, 5070.31 examples/s]
# Loading model: microsoft/deberta-base ...
# pytorch_model.bin: 100% 559M/559M [00:05<00:00, 103MB/s]
# Loading weights: 100% 196/196 [00:00<00:00, 901.38it/s, Materializing param=deberta.encoder.rel_embeddings.weight]
# DebertaForTokenClassification LOAD REPORT from: microsoft/deberta-base
# Key                                     | Status     |
# ----------------------------------------+------------+-
# lm_predictions.lm_head.dense.bias       | UNEXPECTED |
# lm_predictions.lm_head.LayerNorm.weight | UNEXPECTED |
# ...

# %%
# !python ate_train.py
# Out:
# Loading data from ate_data ...
# Loading tokenizer: bert-base-uncased ...
# config.json: 100% 570/570 [00:00<00:00, 1.41MB/s]
# ...
# tokenizer_config.json: 100% 48.0/48.0 [00:00<00:00, 231kB/s]
# vocab.txt: 232kB [00:00, 3.17MB/s]
# tokenizer.json: 466kB [00:00, 4.73MB/s]
# Map: 100% 2736/2736 [00:00<00:00, 3399.65 examples/s]
# Map: 100% 305/305 [00:00<00:00, 4537.44 examples/s]
# Map: 100% 800/800 [00:00<00:00, 4861.79 examples/s]
# Loading model: bert-base-uncased ...
# model.safetensors: 100% 440M/440M [00:04<00:00, 97.7MB/s]
# Loading weights: 100% 197/197 [00:00<00:00, 1413.56it/s, Materializing param=bert.encoder.layer.11.output.dense.weight]
# BertForTokenClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.seq_relationship.bias                  | UNEXPECTED |
# bert.pooler.dense.weight                   | UNEXPECTED |
# ...

# %%
# !python ate_evaluate.py --model_dir ate_output/final --data_dir ate_data_restaurant
# Out:
# Device: cuda
# Loading model …
# Loading weights: 100% 199/199 [00:00<00:00, 880.97it/s, Materializing param=classifier.weight]
# Loading test data …
# Map: 100% 800/800 [00:00<00:00, 4132.52 examples/s]
# Running predictions …
#
# ...
# ATE Evaluation Results
# ...
# Precision : 0.9356
# Recall    : 0.9173
# F1        : 0.9264
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          ASP       0.94      0.92      0.93      1632
#
#    micro avg       0.94      0.92      0.93      1632
#    macro avg       0.94      0.92      0.93      1632
# weighted avg       0.94      0.92      0.93      1632
#
# Results saved → ate_output/final/ate_test_metrics.json

# %%
# !git clone https://github.com/fyZhang66/nlp_final.git
# Out:
# Cloning into 'nlp_final'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 69 (delta 25), reused 51 (delta 16), pack-reused 0 (from 0)
# Receiving objects: 100% (69/69), 1.20 MiB | 3.86 MiB/s, done.
# Resolving deltas: 100% (25/25), done.

# %%
# %cd nlp_final/asc
# !python asc_prepare_data.py
# Out:
# /content/nlp_final/asc
# Parsing training XML ...
# Total examples (excluding 'conflict'): 3602
#   positive: 2164
#   negative: 805
#   neutral: 633
# Saving the dataset (1/1 shards): 100% 2881/2881 [00:00<00:00, 382132.37 examples/s]
# Saving the dataset (1/1 shards): 100% 360/360 [00:00<00:00, 138960.93 examples/s]
# Saving the dataset (1/1 shards): 100% 361/361 [00:00<00:00, 154678.08 examples/s]
#
# Train: 2881 | Val: 360 | Test: 361
# Saved to: asc_data/
#
# Sample examples:
#   [positive] "lunch menu" in "The secret is the lunch menu which offers a complimentary ap..."
#   [negative] "money" in "Overall, not worth the money...."
#   [ neutral] "Food" in "Food and service was okay...."

# %%
# !python asc_train.py
# Out:
# Loading data from asc_data ...
# Loading tokenizer: bert-base-uncased ...
# ...
# config.json: 100% 570/570 [00:00<00:00, 2.22MB/s]
# tokenizer_config.json: 100% 48.0/48.0 [00:00<00:00, 231kB/s]
# vocab.txt: 232kB [00:00, 4.41MB/s]
# tokenizer.json: 466kB [00:00, 5.78MB/s]
# Map: 100% 2881/2881 [00:00<00:00, 7957.66 examples/s]
# Map: 100% 360/360 [00:00<00:00, 8377.53 examples/s]
# Map: 100% 361/361 [00:00<00:00, 8722.28 examples/s]
# Loading model: bert-base-uncased ...
# model.safetensors: 100% 440M/440M [00:02<00:00, 210MB/s]
# Loading weights: 100% 199/199 [00:00<00:00, 905.56it/s, Materializing param=bert.pooler.dense.weight]
# BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# ...

# %%
# !cp "/content/asc_train_deberta (1).py" /content/nlp_final/asc/asc_train_deberta.py
# !python asc_train_deberta.py
# Out:
# Loading data from asc_data ...
# Loading tokenizer: microsoft/deberta-base ...
# config.json: 100% 474/474 [00:00<00:00, 2.21MB/s]
# tokenizer_config.json: 100% 52.0/52.0 [00:00<00:00, 276kB/s]
# ...
# vocab.json: 899kB [00:00, 31.1MB/s]
# merges.txt: 456kB [00:00, 101MB/s]
# Map: 100% 2881/2881 [00:00<00:00, 4653.86 examples/s]
# Map: 100% 360/360 [00:00<00:00, 3276.20 examples/s]
# Map: 100% 361/361 [00:00<00:00, 4671.19 examples/s]
# Loading model: microsoft/deberta-base ...
# pytorch_model.bin: 100% 559M/559M [00:18<00:00, 30.0MB/s]
# Loading weights: 100% 196/196 [00:00<00:00, 1396.08it/s, Materializing param=deberta.encoder.rel_embeddings.weight]
# DebertaForSequenceClassification LOAD REPORT from: microsoft/deberta-base
# Key                                     | Status     |
# ----------------------------------------+------------+-
# lm_predictions.lm_head.LayerNorm.weight | UNEXPECTED |
# lm_predictions.lm_head.LayerNorm.bias   | UNEXPECTED |
# ...
